# %%
a = input("Enter a Number")
# Out:
# Enter a Number 8

# %%
type(a)
# Out:
# str

# %%
a1 = int(input("Enter a Number"))
# Out:
# Enter a Number 8

# %%
type(a1)
# Out:
# int

# %%
a = input("Enter a Number")
 = input("Enter a Number")
a = int(a)
b = int(b)
c = a+b
print(c)
# Out:
# Enter a Number 14
# Enter a Number 12
# 26

# %%
int("abc", 13)
# Out:
# 1845

# %%
int("123",3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int("123",3)
#
# ValueError: invalid literal for int() with base 3: '123'

# %%
int("12",3)
# Out:
# 5

# %%
int(21.45)
# Out:
# 21

# %%
type(int)
# Out:
# type

# %%
int("21.45")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int("21.45")
#
# ValueError: invalid literal for int() with base 10: '21.45'

# %%
float("12.34")
# Out:
# 12.34

# %%
a = input("Enter a Number")
b = input("Enter a Number")
a = float(a)
b = float(b)
c = a+b
print(c)
# Out:
# Enter a Number 12.45
# Enter a Number 13
# 25.45

# %%
# Out:
# ' 12 23'
