# %%
(1000+2000)/200*10
# Out:
# 150.0

# %%
1000/200/10/5/2
# Out:
# 0.05

# %%
2/5/10/200/1000
# Out:
# 2.0000000000000002e-07

# %%
bool("")
# Out:
# False

# %%
bool("python")
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(0.000000)
# Out:
# False

# %%
bool(0+0j)
# Out:
# False

# %%
bool("abc")
# Out:
# True

# %%
bool([1,2,3,4])
# Out:
# True

# %%
bool((1,2,3,4))
# Out:
# True

# %%
bool({1,2,3,4})
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool("0")
# Out:
# True

# %%
bool([0])
# Out:
# True

# %%
bool((0))
# Out:
# False

# %%
bool({0})
# Out:
# True

# %%
a = 0 
print(type(a))
# Out:
# <class 'int'>

# %%
a = [0] 
print(type(0))
# Out:
# <class 'int'>

# %%
a = (10) 
print(type(a))
# Out:
# <class 'int'>

# %%
a = 10 
print('positive')
print('Negative')
print('zero')
# Out:
# positive
# Negative
# zero

# %%
a=10 
if False: 
    print("Negative")
if False: 
    print("zero")
if True:   
    print("positive")
# Out:
# positive

# %%
a=100
if a==0: 
    print("Positive")
if a>0: 
    print("Negative") 
if a=0: 
    print("positive")
# Out:
#   Cell In[35], line 6
#     if a=0:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
if True: 
    print("Hii") 
else: 
    print("Hello")
# Out:
# Hii

# %%
if False: 
    print("Hii") 
else: 
    print("Hello")
# Out:
# Hello

# %%
print("started")
if 1: 
    print("Hii")
else: 
    print("Hello")
    print("Ended")
# Out:
# started
# Hii

# %%
print("started")
if 0: 
    print("Hii")
else: 
    print("Hello")
    print("Ended")
# Out:
# started
# Hello
# Ended

# %%
print("started")
if (0): 
    print("Hii")
else: 
    print("Hello")
    print("Ended")
# Out:
# started
# Hello
# Ended

# %%
a=100
if a==0: 
    print("Zero")
else: 
   if a>0: 
    print("positive")
   else: 
    print("Negative")
# Out:
# positive
