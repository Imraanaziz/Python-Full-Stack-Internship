# %%
2+3+2j
# Out:
# (5+2j)

# %%
20.333+40.333
# Out:
# 60.666

# %%
1+True
# Out:
# 2

# %%
a = '27'
b = 34 
print(int(a)+b)
# Out:
# 61

# %%
a = 'A,B,C'
print(type(a))
# Out:
# <class 'str'>

# %%
a = 10
b = 12 
a>b
# Out:
# False

# %%
a = '10'
b = '9' 
a<b
# Out:
# True

# %%
a = 'Apple'
b = 'apple'
c = 'Apple'
a>b
# Out:
# False

# %%
a = [1,2,3,4]
b = [0,6,3,4]
a>b
# Out:
# True

# %%
10<10
# Out:
# False

# %%
a = [1,2]
b = [1,2]
a>b
# Out:
# False

# %%
a = [1,2]
b = [1,2,3]
a>b
# Out:
# False

# %%
a = [1,2,3]
b = [1,2,3]
a==b
# Out:
# True

# %%
a = {1,2,3}
b = {1,2,3}
a==b
# Out:
# True

# %%
a = {1,2,3}
b = {1,3,2}
a==b
# Out:
# True

# %%
2**6
# Out:
# 64

# %%
8/4
# Out:
# 2.0

# %%
7/3
# Out:
# 2.3333333333333335

# %%
a = 10 
b = 12 
a>b
# Out:
# False

# %%
a = '10'
b = '12'
a<b
# Out:
# True

# %%
a = ['10', '9', '5', '2']
print(a)
# Out:
# ['10', '9', '5', '2']

# %%
a = ['10', '9', '5', '2']
print((a))
# Out:
# ['10', '9', '5', '2']

# %% [markdown]
# # Operators

# %%
a = 1000
b = 2000
a<b
# Out:
# True

# %%
a = 20.40
b = 30.50
a+b
# Out:
# 50.9

# %%
a = 12 
b = 10.45
a+b
# Out:
# 22.45

# %%
a = 'abc'
b = 'def' 
a+b
# Out:
# 'abcdef'

# %%
a = 'abc'
b = 'def' 
a<b
# Out:
# True

# %%
a = True 
b = 23 
a+b
# Out:
# 24

# %%
a = [1,2,3]
b = [4,5,6]
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1,2,3]
b = [4,5,6]
a>b
# Out:
# False

# %%
a = [1,2,3]
b = [4,5,6]
a<b
# Out:
# True

# %%
a = {'a' 'imran' 'arshad'} 
print(type(a))
# Out:
# <class 'set'>

# %%
a = (10, 59, 78)
b = (34, 57, 89)
a+b
# Out:
# (10, 59, 78, 34, 57, 89)

# %%
a = '89'
b = 22
print(int(a)+b)
# Out:
# 111

# %%
a = ['This is my first song pal pal jeena']
print(a)
# Out:
# ['This is my first song pal pal jeena']

# %%
li = [1,2,3,4,5]
li
# Out:
# [1, 2, 3, 4, 5]

# %%
len(li)
# Out:
# 5

# %%
s1 = {1,2,3,4,5}
s1 = ('remove'

# %%
s1=set(range(19,27))
s1
# Out:
# {19, 20, 21, 22, 23, 24, 25, 26}

# %%
len(s1)
# Out:
# 8

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 s1.remove(5)
#
# KeyError: 5
